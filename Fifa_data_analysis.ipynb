# %% [markdown]
# <a href="https://colab.research.google.com/github/phk16/jupyterNotebooks/blob/main/Fifa_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src = "https://www.bits-pilani.ac.in/Uploads/Campus/BITS_university_logo.gif">

# %% [markdown]
# <h3>Objective</h3>
# <h4>To find best players from each positions with their age, nationality, club based on their Potential Scores</h4>

# %% [markdown]
# <h4>Import the libraries needed</h4>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
sns.set_style("white")
sns.set(rc={"axes.facecolor":"#05f28f", "figure.facecolor":"#c5f0de",
            "axes.grid":True, "grid.color":"black", "axes.edgecolor":"black",
            "grid.linestyle": u"-", "axes.labelcolor": "black", "font.family": [u"DejaVu Sans"],
            "text.color": "black", "xtick.color": "black", "ytick.color": "black",
            "legend.facecolor":"#65cee8", "legend.frameon": True, "legend.edgecolor":"#27a1bf"})
sns.set_context("poster",font_scale = 0.7)

palette = ["#003049","#d62828","#f77f00","#fcbf49","#eae2b7", "#f27a02","#97f7f6","#150647"]
palette_cmap = ["#272716","#6c2411","#cc3f18","#db6400","#ae0d13"]
palette_cmap_n = np.array(["#272716","#6c2411","#cc3f18","#db6400","#ae0d13"])
cell_hover = {  # for row hover use <tr> instead of <td>
    'selector': 'td:hover',
    'props': 'background-color: #f0f099; color: black'
#     'props': [('background-color', '#ffffb3'; 'color')].
}
index_names = {
    'selector': '.index_name',
    'props': 'font-style: italic; color: black; font-weight:normal;'
}
headers = {
    'selector': 'th:not(.index_name)',
    'props': 'background-color: #c5f0de; color: black;'
}

table_styles = [cell_hover, index_names, headers]
set_properties = {"background-color": "#05f28f","color":"black","border": "1.3px solid black"}

# %% [markdown]
# <h4> Load data and store in dataframe </h4>

# %%
# %%time
pd_df=pd.read_csv('dvi-a2-ps1-data.csv', na_values='nan')
# Out:
# CPU times: user 160 ms, sys: 24.2 ms, total: 185 ms
# Wall time: 187 ms

# %% [markdown]
# <h4>Find out  what type of variable you are dealing with. This will help you find the right visualization method for that variable.</p>

# %%
pd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10412 entries, 0 to 10411
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                10412 non-null  int64
#  1   ID                        10412 non-null  int64
#  2   Name                      10412 non-null  object
#  3   Age                       10412 non-null  int64
#  4   Photo                     10412 non-null  object
#  5   Nationality               10412 non-null  object
#  6   Flag                      10412 non-null  object
#  7   Overall                   10412 non-null  int64
#  8   Potential                 10412 non-null  int64
#  9   Club                      10247 non-null  object
#  10  Club Logo                 10412 non-null  object
#  11  Value                     10412 non-null  object
#  12  Wage                      10412 non-null  object
#  13  Special                   10412 non-null  int64
#  14  Preferred Foot            10412 non-null  object
#  15  International Reputation  10412 non-null  int64
#  16  Weak Foot                 10412 non-null  int64
#  17  Skill Moves               10412 non-null  int64
#  18  Work Rate                 10412 non-null  object
#  19  Body Type                 10412 non-null  object
#  20  Real Face                 10412 non-null  object
#  21  Position                  10408 non-null  object
#  22  Jersey Number             10408 non-null  float64
#  23  Joined                    9421 non-null   object
#  24  Loaned From               826 non-null    object
#  25  Contract Valid Until      10247 non-null  object
#  26  Height                    10412 non-null  object
#  27  Weight                    10412 non-null  object
#  28  LS                        9444 non-null   object
#  29  ST                        9444 non-null   object
#  30  RS                        9444 non-null   object
#  31  LW                        9444 non-null   object
#  32  LF                        9444 non-null   object
#  33  CF                        9444 non-null   object
#  34  RF                        9444 non-null   object
#  35  RW                        9444 non-null   object
#  36  LAM                       9444 non-null   object
#  37  CAM                       9444 non-null   object
#  38  RAM                       9444 non-null   object
#  39  LM                        9444 non-null   object
#  40  LCM                       9444 non-null   object
#  41  CM                        9444 non-null   object
#  42  RCM                       9444 non-null   object
#  43  RM                        9444 non-null   object
#  44  LWB                       9444 non-null   object
#  45  LDM                       9444 non-null   object
#  46  CDM                       9444 non-null   object
#  47  RDM                       9444 non-null   object
#  48  RWB                       9444 non-null   object
#  49  LB                        9444 non-null   object
#  50  LCB                       9444 non-null   object
#  51  CB                        9444 non-null   object
#  52  RCB                       9444 non-null   object
#  53  RB                        9444 non-null   object
#  54  Crossing                  10412 non-null  int64
#  55  Finishing                 10412 non-null  int64
#  56  HeadingAccuracy           10412 non-null  int64
#  57  ShortPassing              10412 non-null  int64
#  58  Volleys                   10412 non-null  int64
#  59  Dribbling                 10412 non-null  int64
#  60  Curve                     10412 non-null  int64
#  61  FKAccuracy                10412 non-null  int64
#  62  LongPassing               10412 non-null  int64
#  63  BallControl               10412 non-null  int64
#  64  Acceleration              10412 non-null  int64
#  65  SprintSpeed               10412 non-null  int64
#  66  Agility                   10412 non-null  int64
#  67  Reactions                 10412 non-null  int64
#  68  Balance                   10412 non-null  int64
#  69  ShotPower                 10412 non-null  int64
#  70  Jumping                   10412 non-null  int64
#  71  Stamina                   10412 non-null  int64
#  72  Strength                  10412 non-null  int64
#  73  LongShots                 10412 non-null  int64
#  74  Aggression                10412 non-null  int64
#  75  Interceptions             10412 non-null  int64
#  76  Positioning               10411 non-null  float64
#  77  Vision                    10411 non-null  float64
#  78  Penalties                 10411 non-null  float64
#  79  Composure                 10411 non-null  float64
#  80  Marking                   10411 non-null  float64
#  81  StandingTackle            10411 non-null  float64
#  82  SlidingTackle             10411 non-null  float64
#  83  GKDiving                  10411 non-null  float64
#  84  GKHandling                10411 non-null  float64
#  85  GKKicking                 10411 non-null  float64
#  86  GKPositioning             10411 non-null  float64
#  87  GKReflexes                10411 non-null  float64
#  88  Release Clause            9416 non-null   object
# dtypes: float64(13), int64(31), object(45)
# memory usage: 7.1+ MB

# %%
print(pd_df.transpose().head(10))
# Out:
#                                                       0      \
# Unnamed: 0                                                0
# ID                                                   158023
# Name                                               L. Messi
# Age                                                      31
# Photo        https://cdn.sofifa.org/players/4/19/158023.png
# Nationality                                       Argentina
# Flag                    https://cdn.sofifa.org/flags/52.png
# Overall                                                  94
# Potential                                                94
# Club                                           FC Barcelona
#
#                                                      1      \
# Unnamed: 0                                               1
# ID                                                   20801
# Name                                     Cristiano Ronaldo
# Age                                                     33
# Photo        https://cdn.sofifa.org/players/4/19/20801.png
# Nationality                                       Portugal
# Flag                   https://cdn.sofifa.org/flags/38.png
# Overall                                                 94
# Potential                                               94
# Club                                              Juventus
#
#                                                       2      \
# Unnamed: 0                                                2
# ID                                                   190871
# Name                                              Neymar Jr
# Age                                                      26
# Photo        https://cdn.sofifa.org/players/4/19/190871.png
# Nationality                                          Brazil
# Flag                    https://cdn.sofifa.org/flags/54.png
# Overall                                                  92
# Potential                                                93
# Club                                    Paris Saint-Germain
#
#                                                       3      \
# Unnamed: 0                                                3
# ID                                                   193080
# Name                                                 De Gea
# Age                                                      27
# Photo        https://cdn.sofifa.org/players/4/19/193080.png
# Nationality                                           Spain
# Flag                    https://cdn.sofifa.org/flags/45.png
# Overall                                                  91
# Potential                                                93
# Club                                      Manchester United
#
#                                                       4      \
# Unnamed: 0                                                4
# ID                                                   192985
# Name                                           K. De Bruyne
# Age                                                      27
# Photo        https://cdn.sofifa.org/players/4/19/192985.png
# Nationality                                         Belgium
# Flag                     https://cdn.sofifa.org/flags/7.png
# Overall                                                  91
# Potential                                                92
# Club                                        Manchester City
#
#                                                       5      \
# Unnamed: 0                                                5
# ID                                                   183277
# Name                                              E. Hazard
# Age                                                      27
# Photo        https://cdn.sofifa.org/players/4/19/183277.png
# Nationality                                         Belgium
# Flag                     https://cdn.sofifa.org/flags/7.png
# Overall                                                  91
# Potential                                                91
# Club                                                Chelsea
#
#                                                       6      \
# Unnamed: 0                                                6
# ID                                                   177003
# Name                                              L. Modrić
# Age                                                      32
# Photo        https://cdn.sofifa.org/players/4/19/177003.png
# Nationality                                         Croatia
# Flag                    https://cdn.sofifa.org/flags/10.png
# Overall                                                  91
# Potential                                                91
# Club                                            Real Madrid
#
#                                                       7      \
# Unnamed: 0                                                7
# ID                                                   176580
# Name                                              L. Suárez
# Age                                                      31
# Photo        https://cdn.sofifa.org/players/4/19/176580.png
# Nationality                                         Uruguay
# Flag                    https://cdn.sofifa.org/flags/60.png
# Overall                                                  91
# Potential                                                91
# Club                                           FC Barcelona
#
#                                                       8      \
# Unnamed: 0                                                8
# ID                                                   155862
# Name                                           Sergio Ramos
# Age                                                      32
# Photo        https://cdn.sofifa.org/players/4/19/155862.png
# Nationality                                           Spain
# Flag                    https://cdn.sofifa.org/flags/45.png
# Overall                                                  91
# Potential                                                91
# Club                                            Real Madrid
#
#                                                       9      ...  \
# Unnamed: 0                                                9  ...
# ID                                                   200389  ...
# Name                                               J. Oblak  ...
# Age                                                      25  ...
# Photo        https://cdn.sofifa.org/players/4/19/200389.png  ...
# Nationality                                        Slovenia  ...
# Flag                    https://cdn.sofifa.org/flags/44.png  ...
# Overall                                                  90  ...
# Potential                                                93  ...
# Club                                        Atlético Madrid  ...
#
#                                                       10402  \
# Unnamed: 0                                            10402
# ID                                                   227446
# Name                                            K. van Veen
# Age                                                      27
# Photo        https://cdn.sofifa.org/players/4/19/227446.png
# Nationality                                     Netherlands
# Flag                    https://cdn.sofifa.org/flags/34.png
# Overall                                                  65
# Potential                                                66
# Club                                       Northampton Town
#
#                                                       10403  \
# Unnamed: 0                                            10403
# ID                                                   241014
# Name                                           N. Garmendia
# Age                                                      20
# Photo        https://cdn.sofifa.org/players/4/19/241014.png
# Nationality                                           Spain
# Flag                    https://cdn.sofifa.org/flags/45.png
# Overall                                                  65
# Potential                                                76
# Club                                                Udinese
#
#                                                       10404  \
# Unnamed: 0                                            10404
# ID                                                   188278
# Name                                          M. Birighitti
# Age                                                      27
# Photo        https://cdn.sofifa.org/players/4/19/188278.png
# Nationality                                       Australia
# Flag                   https://cdn.sofifa.org/flags/195.png
# Overall                                                  65
# Potential                                                66
# Club                                      Melbourne City FC
#
#                                                       10405  \
# Unnamed: 0                                            10405
# ID                                                   198007
# Name                                           E. Alexander
# Age                                                      30
# Photo        https://cdn.sofifa.org/players/4/19/198007.png
# Nationality                                   United States
# Flag                    https://cdn.sofifa.org/flags/95.png
# Overall                                                  65
# Potential                                                65
# Club                                         Houston Dynamo
#
#                                                       10406  \
# Unnamed: 0                                            10406
# ID                                                   223095
# Name                                   F. Palacios Martínez
# Age                                                      23
# Photo        https://cdn.sofifa.org/players/4/19/223095.png
# Nationality                                           Spain
# Flag                    https://cdn.sofifa.org/flags/45.png
# Overall                                                  65
# Potential                                                71
# Club                                         1. FC Nürnberg
#
#                                                       10407  \
# Unnamed: 0                                            10407
# ID                                                   223607
# Name                                              Luis Ruiz
# Age                                                      26
# Photo        https://cdn.sofifa.org/players/4/19/223607.png
# Nationality                                           Spain
# Flag                    https://cdn.sofifa.org/flags/45.png
# Overall                                                  65
# Potential                                                68
# Club                                                CD Lugo
#
#                                                       10408  \
# Unnamed: 0                                            10408
# ID                                                   226679
# Name                                              A. Hunter
# Age                                                      22
# Photo        https://cdn.sofifa.org/players/4/19/226679.png
# Nationality                                         England
# Flag                    https://cdn.sofifa.org/flags/14.png
# Overall                                                  65
# Potential                                                73
# Club                                         Fleetwood Town
#
#                                                       10409  \
# Unnamed: 0                                            10409
# ID                                                   232311
# Name                                               L. Owusu
# Age                                                      21
# Photo        https://cdn.sofifa.org/players/4/19/232311.png
# Nationality                                     Netherlands
# Flag                    https://cdn.sofifa.org/flags/34.png
# Overall                                                  65
# Potential                                                73
# Club                                          De Graafschap
#
#                                                       10410  \
# Unnamed: 0                                            10410
# ID                                                   209784
# Name                                               J. Phojo
# Age                                                      25
# Photo        https://cdn.sofifa.org/players/4/19/209784.png
# Nationality                                          France
# Flag                    https://cdn.sofifa.org/flags/18.png
# Overall                                                  65
# Potential                                                66
# Club                                       Clermont Foot 63
#
#                                                       10411
# Unnamed: 0                                            10411
# ID                                                   213368
# Name                                            L. Rougeaux
# Age                                                      24
# Photo        https://cdn.sofifa.org/players/4/19/213368.png
# Nationality                                          France
# Flag                    https://cdn.sofifa.org/flags/18.png
# Overall                                                  65
# Potential                                                69
# Club                                            KV Kortrijk
#
# [10 rows x 10412 columns]

# %% [markdown]
# ### Question 1
# <h4>Fill the missing value for the continous variables with Mean(average) for proper data visualization.
# <br><br>
#     Preprocess height - convert data in  format xx'xx to xx.xx Remove "nan" with Mode and convert the column to numerical.
# <br><br>
#     Preprocess weight - convert data in  format xxlbs to xx Remove "nan" with Mode and convert the column to numerical.
# <h4>Do Univariate anlaysis for outliers detection for height and weight.
# <br><br>
# <h4>Write the python code in the below cell to create appropriate visual to perform the above task.
# <h4> Answer in markdown cells below the visual
# <br><br>
# <ol>
#     <li>Summarise your findings from the visual.</li>
#     <li>The reason for selecting the chart type you did.</li>
#     <li>Mention the pre-attentive attributes used.(atleast 2)</li>
#     <li>Mention the gestalt principles used.(atleast 2)</li>
# </ol>

# %%
def dataType(col):
  list1 = col.index
  list2=[]
  for x in list1:
    temp =pd_df[x].dtype
    list2.append(temp)
  list3 = pd.Series(list2, index=list1)
  return list3

# %%
missing_values = pd_df.isnull().sum().sort_values(ascending = False)
dtype7 = dataType(missing_values)
percentage_missing_values = (missing_values/len(pd_df))*100
pd.DataFrame(pd.concat([missing_values, percentage_missing_values, dtype7], axis = 1, keys= ['Missing values', '% Missing', 'type'])).style.set_table_styles(table_styles).set_properties(**set_properties)
# Out:
# <style type="text/css">
# #T_b67ed td:hover {
#   background-color: #f0f099;
#   color: black;
# }
# #T_b67ed .index_name {
#   font-style: italic;
#   color: black;
#   font-weight: normal;
# }
# #T_b67ed th:not(.index_name) {
#   background-color: #c5f0de;
#   color: black;
# }
# #T_b67ed_row0_col0, #T_b67ed_row0_col1, #T_b67ed_row0_col2, #T_b67ed_row1_col0, #T_b67ed_row1_col1, #T_b67ed_row1_col2, #T_b67ed_row2_col0, #T_b67ed_row2_col1, #T_b67ed_row2_col2, #T_b67ed_row3_col0, #T_b67ed_row3_col1, #T_b67ed_row3_col2, #T_b67ed_row4_col0, #T_b67ed_row4_col1, #T_b67ed_row4_col2, #T_b67ed_row5_col0, #T_b67ed_row5_col1, #T_b67ed_row5_col2, #T_b67ed_row6_col0, #T_b67ed_row6_col1, #T_b67ed_row6_col2, #T_b67ed_row7_col0, #T_b67ed_row7_col1, #T_b67ed_row7_col2, #T_b67ed_row8_col0, #T_b67ed_row8_col1, #T_b67ed_row8_col2, #T_b67ed_row9_col0, #T_b67ed_row9_col1, #T_b67ed_row9_col2, #T_b67ed_row10_col0, #T_b67ed_row10_col1, #T_b67ed_row10_col2, #T_b67ed_row11_col0, #T_b67ed_row11_col1, #T_b67ed_row11_col2, #T_b67ed_row12_col0, #T_b67ed_row12_col1, #T_b67ed_row12_col2, #T_b67ed_row13_col0, #T_b67ed_row13_col1, #T_b67ed_row13_col2, #T_b67ed_row14_col0, #T_b67ed_row14_col1, #T_b67ed_row14_col2, #T_b67ed_row15_col0, #T_b67ed_row15_col1, #T_b67ed_row15_col2, #T_b67ed_row16_col0, #T_b67ed_row16_col1, #T_b67ed_row16_col2, #T_b67ed_row17_col0, #T_b67ed_row17_col1, #T_b67ed_row17_col2, #T_b67ed_row18_col0, #T_b67ed_row18_col1, #T_b67ed_row18_col2, #T_b67ed_row19_col0, #T_b67ed_row19_col1, #T_b67ed_row19_col2, #T_b67ed_row20_col0, #T_b67ed_row20_col1, #T_b67ed_row20_col2, #T_b67ed_row21_col0, #T_b67ed_row21_col1, #T_b67ed_row21_col2, #T_b67ed_row22_col0, #T_b67ed_row22_col1, #T_b67ed_row22_col2, #T_b67ed_row23_col0, #T_b67ed_row23_col1, #T_b67ed_row23_col2, #T_b67ed_row24_col0, #T_b67ed_row24_col1, #T_b67ed_row24_col2, #T_b67ed_row25_col0, #T_b67ed_row25_col1, #T_b67ed_row25_col2, #T_b67ed_row26_col0, #T_b67ed_row26_col1, #T_b67ed_row26_col2, #T_b67ed_row27_col0, #T_b67ed_row27_col1, #T_b67ed_row27_col2, #T_b67ed_row28_col0, #T_b67ed_row28_col1, #T_b67ed_row28_col2, #T_b67ed_row29_col0, #T_b67ed_row29_col1, #T_b67ed_row29_col2, #T_b67ed_row30_col0, #T_b67ed_row30_col1, #T_b67ed_row30_col2, #T_b67ed_row31_col0, #T_b67ed_row31_col1, #T_b67ed_row31_col2, #T_b67ed_row32_col0, #T_b67ed_row32_col1, #T_b67ed_row32_col2, #T_b67ed_row33_col0, #T_b67ed_row33_col1, #T_b67ed_row33_col2, #T_b67ed_row34_col0, #T_b67ed_row34_col1, #T_b67ed_row34_col2, #T_b67ed_row35_col0, #T_b67ed_row35_col1, #T_b67ed_row35_col2, #T_b67ed_row36_col0, #T_b67ed_row36_col1, #T_b67ed_row36_col2, #T_b67ed_row37_col0, #T_b67ed_row37_col1, #T_b67ed_row37_col2, #T_b67ed_row38_col0, #T_b67ed_row38_col1, #T_b67ed_row38_col2, #T_b67ed_row39_col0, #T_b67ed_row39_col1, #T_b67ed_row39_col2, #T_b67ed_row40_col0, #T_b67ed_row40_col1, #T_b67ed_row40_col2, #T_b67ed_row41_col0, #T_b67ed_row41_col1, #T_b67ed_row41_col2, #T_b67ed_row42_col0, #T_b67ed_row42_col1, #T_b67ed_row42_col2, #T_b67ed_row43_col0, #T_b67ed_row43_col1, #T_b67ed_row43_col2, #T_b67ed_row44_col0, #T_b67ed_row44_col1, #T_b67ed_row44_col2, #T_b67ed_row45_col0, #T_b67ed_row45_col1, #T_b67ed_row45_col2, #T_b67ed_row46_col0, #T_b67ed_row46_col1, #T_b67ed_row46_col2, #T_b67ed_row47_col0, #T_b67ed_row47_col1, #T_b67ed_row47_col2, #T_b67ed_row48_col0, #T_b67ed_row48_col1, #T_b67ed_row48_col2, #T_b67ed_row49_col0, #T_b67ed_row49_col1, #T_b67ed_row49_col2, #T_b67ed_row50_col0, #T_b67ed_row50_col1, #T_b67ed_row50_col2, #T_b67ed_row51_col0, #T_b67ed_row51_col1, #T_b67ed_row51_col2, #T_b67ed_row52_col0, #T_b67ed_row52_col1, #T_b67ed_row52_col2, #T_b67ed_row53_col0, #T_b67ed_row53_col1, #T_b67ed_row53_col2, #T_b67ed_row54_col0, #T_b67ed_row54_col1, #T_b67ed_row54_col2, #T_b67ed_row55_col0, #T_b67ed_row55_col1, #T_b67ed_row55_col2, #T_b67ed_row56_col0, #T_b67ed_row56_col1, #T_b67ed_row56_col2, #T_b67ed_row57_col0, #T_b67ed_row57_col1, #T_b67ed_row57_col2, #T_b67ed_row58_col0, #T_b67ed_row58_col1, #T_b67ed_row58_col2, #T_b67ed_row59_col0, #T_b67ed_row59_col1, #T_b67ed_row59_col2, #T_b67ed_row60_col0, #T_b67ed_row60_col1, #T_b67ed_row60_col2, #T_b67ed_row61_col0, #T_b67ed_row61_col1, #T_b67ed_row61_col2, #T_b67ed_row62_col0, #T_b67ed_row62_col1, #T_b67ed_row62_col2, #T_b67ed_row63_col0, #T_b67ed_row63_col1, #T_b67ed_row63_col2 ...
#   background-color: #05f28f;
#   color: black;
#   border: 1.3px solid black;
# }
# </style>
# <table id="T_b67ed" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b67ed_level0_col0" class="col_heading level0 col0" >Missing values</th>
#       <th id="T_b67ed_level0_col1" class="col_heading level0 col1" >% Missing</th>
#       <th id="T_b67ed_level0_col2" class="col_heading level0 col2" >type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b67ed_level0_row0" class="row_heading level0 row0" >Loaned From</th>
#       <td id="T_b67ed_row0_col0" class="data row0 col0" >9586</td>
#       <td id="T_b67ed_row0_col1" class="data row0 col1" >92.066846</td>
#       <td id="T_b67ed_row0_col2" class="data row0 col2" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b67ed_level0_row1" class="row_heading level0 row1" >Release Clause</th>
#       <td id="T_b67ed_row1_col0" class="data row1 col0" >996</td>
#       <td id="T_b67ed_row1_col1" class="data row1 col1" >9.565886</td>
#       <td id="T_b67ed_row1_col2" class="data row1 col2" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b67ed_level0_row2" class="row_heading level0 row2" >Joined</th>
#       <td id="T_b67ed_row2_col0" class="data row2 col0" >991</td>
#       <td id="T_b67ed_row2_col1" class="data row2 col1" >9.517864</td>
#       <td id="T_b67ed_row2_col2" class="data row2 col2" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b67ed_level0_row3" class="row_heading level0 row3" >LS</th>
#       <td id="T_b67ed_row3_col0" class="data row3 col0" >968</td>
#       <td id="T_b67ed_row3_col1" class="data row3 col1" >9.296965</td>
#       <td id="T_b67ed_row3_col2" class="data row3 col2" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b67ed_level0_row4" class="row_heading level0 row4" >RS</th>
#       <td id="T_b67ed_row4_col0" class="data row4 col0" >968</td>
#       <td id="T_b67ed_row4_col1" class="data row4 col1" >9.296965</td>
#       <td id="T_b67ed_row4_col2" class="data row4 col2" >object</td>
#     </tr>
#     <tr>
#       <th id="T_b67ed_level0_row5" class="row_heading level0 row5" >LW</th>
#       <td id="T_b67ed_row5_col0" class="data row5 col0" >968</td>
#       <td id="T_b

# %%
pd_df['Height'] =  pd_df['Height'].apply(lambda x: str(x).replace("\'", "."))
pd_df['Height'] =  pd_df['Height'].fillna(pd_df['Height'].mode()[0])
temp_mode = pd_df['Height'].mode()[0]
pd_df['Height'] =  pd_df['Height'].apply(lambda x: temp_mode if x == 'nan' else x )
pd_df['Height'] = pd_df['Height'].apply(pd.to_numeric)

# %%
pd_df['Weight'] =  pd_df['Weight'].apply(lambda x: str(x).replace("lbs", ""))
pd_df['Weight'] =  pd_df['Weight'].fillna(pd_df['Weight'].mode()[0])
temp_mode = pd_df['Weight'].mode()[0]
pd_df['Weight'] =  pd_df['Weight'].apply(lambda x: temp_mode if x == 'nan' else x )
pd_df['Weight'] = pd_df['Weight'].apply(pd.to_numeric)

# %%
pd_df_null = pd_df.fillna(pd_df.mean())

# %%
missing_values = pd_df_null.isnull().sum().sort_values(ascending = False)
dtype7 = dataType(missing_values)
percentage_missing_values = (missing_values/len(pd_df))*100
pd.DataFrame(pd.concat([missing_values, percentage_missing_values, dtype7], axis = 1, keys= ['Missing values', '% Missing', 'type'])).style.set_table_styles(table_styles).set_properties(**set_properties)
# Out:
# <style type="text/css">
# #T_5522a td:hover {
#   background-color: #f0f099;
#   color: black;
# }
# #T_5522a .index_name {
#   font-style: italic;
#   color: black;
#   font-weight: normal;
# }
# #T_5522a th:not(.index_name) {
#   background-color: #c5f0de;
#   color: black;
# }
# #T_5522a_row0_col0, #T_5522a_row0_col1, #T_5522a_row0_col2, #T_5522a_row1_col0, #T_5522a_row1_col1, #T_5522a_row1_col2, #T_5522a_row2_col0, #T_5522a_row2_col1, #T_5522a_row2_col2, #T_5522a_row3_col0, #T_5522a_row3_col1, #T_5522a_row3_col2, #T_5522a_row4_col0, #T_5522a_row4_col1, #T_5522a_row4_col2, #T_5522a_row5_col0, #T_5522a_row5_col1, #T_5522a_row5_col2, #T_5522a_row6_col0, #T_5522a_row6_col1, #T_5522a_row6_col2, #T_5522a_row7_col0, #T_5522a_row7_col1, #T_5522a_row7_col2, #T_5522a_row8_col0, #T_5522a_row8_col1, #T_5522a_row8_col2, #T_5522a_row9_col0, #T_5522a_row9_col1, #T_5522a_row9_col2, #T_5522a_row10_col0, #T_5522a_row10_col1, #T_5522a_row10_col2, #T_5522a_row11_col0, #T_5522a_row11_col1, #T_5522a_row11_col2, #T_5522a_row12_col0, #T_5522a_row12_col1, #T_5522a_row12_col2, #T_5522a_row13_col0, #T_5522a_row13_col1, #T_5522a_row13_col2, #T_5522a_row14_col0, #T_5522a_row14_col1, #T_5522a_row14_col2, #T_5522a_row15_col0, #T_5522a_row15_col1, #T_5522a_row15_col2, #T_5522a_row16_col0, #T_5522a_row16_col1, #T_5522a_row16_col2, #T_5522a_row17_col0, #T_5522a_row17_col1, #T_5522a_row17_col2, #T_5522a_row18_col0, #T_5522a_row18_col1, #T_5522a_row18_col2, #T_5522a_row19_col0, #T_5522a_row19_col1, #T_5522a_row19_col2, #T_5522a_row20_col0, #T_5522a_row20_col1, #T_5522a_row20_col2, #T_5522a_row21_col0, #T_5522a_row21_col1, #T_5522a_row21_col2, #T_5522a_row22_col0, #T_5522a_row22_col1, #T_5522a_row22_col2, #T_5522a_row23_col0, #T_5522a_row23_col1, #T_5522a_row23_col2, #T_5522a_row24_col0, #T_5522a_row24_col1, #T_5522a_row24_col2, #T_5522a_row25_col0, #T_5522a_row25_col1, #T_5522a_row25_col2, #T_5522a_row26_col0, #T_5522a_row26_col1, #T_5522a_row26_col2, #T_5522a_row27_col0, #T_5522a_row27_col1, #T_5522a_row27_col2, #T_5522a_row28_col0, #T_5522a_row28_col1, #T_5522a_row28_col2, #T_5522a_row29_col0, #T_5522a_row29_col1, #T_5522a_row29_col2, #T_5522a_row30_col0, #T_5522a_row30_col1, #T_5522a_row30_col2, #T_5522a_row31_col0, #T_5522a_row31_col1, #T_5522a_row31_col2, #T_5522a_row32_col0, #T_5522a_row32_col1, #T_5522a_row32_col2, #T_5522a_row33_col0, #T_5522a_row33_col1, #T_5522a_row33_col2, #T_5522a_row34_col0, #T_5522a_row34_col1, #T_5522a_row34_col2, #T_5522a_row35_col0, #T_5522a_row35_col1, #T_5522a_row35_col2, #T_5522a_row36_col0, #T_5522a_row36_col1, #T_5522a_row36_col2, #T_5522a_row37_col0, #T_5522a_row37_col1, #T_5522a_row37_col2, #T_5522a_row38_col0, #T_5522a_row38_col1, #T_5522a_row38_col2, #T_5522a_row39_col0, #T_5522a_row39_col1, #T_5522a_row39_col2, #T_5522a_row40_col0, #T_5522a_row40_col1, #T_5522a_row40_col2, #T_5522a_row41_col0, #T_5522a_row41_col1, #T_5522a_row41_col2, #T_5522a_row42_col0, #T_5522a_row42_col1, #T_5522a_row42_col2, #T_5522a_row43_col0, #T_5522a_row43_col1, #T_5522a_row43_col2, #T_5522a_row44_col0, #T_5522a_row44_col1, #T_5522a_row44_col2, #T_5522a_row45_col0, #T_5522a_row45_col1, #T_5522a_row45_col2, #T_5522a_row46_col0, #T_5522a_row46_col1, #T_5522a_row46_col2, #T_5522a_row47_col0, #T_5522a_row47_col1, #T_5522a_row47_col2, #T_5522a_row48_col0, #T_5522a_row48_col1, #T_5522a_row48_col2, #T_5522a_row49_col0, #T_5522a_row49_col1, #T_5522a_row49_col2, #T_5522a_row50_col0, #T_5522a_row50_col1, #T_5522a_row50_col2, #T_5522a_row51_col0, #T_5522a_row51_col1, #T_5522a_row51_col2, #T_5522a_row52_col0, #T_5522a_row52_col1, #T_5522a_row52_col2, #T_5522a_row53_col0, #T_5522a_row53_col1, #T_5522a_row53_col2, #T_5522a_row54_col0, #T_5522a_row54_col1, #T_5522a_row54_col2, #T_5522a_row55_col0, #T_5522a_row55_col1, #T_5522a_row55_col2, #T_5522a_row56_col0, #T_5522a_row56_col1, #T_5522a_row56_col2, #T_5522a_row57_col0, #T_5522a_row57_col1, #T_5522a_row57_col2, #T_5522a_row58_col0, #T_5522a_row58_col1, #T_5522a_row58_col2, #T_5522a_row59_col0, #T_5522a_row59_col1, #T_5522a_row59_col2, #T_5522a_row60_col0, #T_5522a_row60_col1, #T_5522a_row60_col2, #T_5522a_row61_col0, #T_5522a_row61_col1, #T_5522a_row61_col2, #T_5522a_row62_col0, #T_5522a_row62_col1, #T_5522a_row62_col2, #T_5522a_row63_col0, #T_5522a_row63_col1, #T_5522a_row63_col2 ...
#   background-color: #05f28f;
#   color: black;
#   border: 1.3px solid black;
# }
# </style>
# <table id="T_5522a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5522a_level0_col0" class="col_heading level0 col0" >Missing values</th>
#       <th id="T_5522a_level0_col1" class="col_heading level0 col1" >% Missing</th>
#       <th id="T_5522a_level0_col2" class="col_heading level0 col2" >type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5522a_level0_row0" class="row_heading level0 row0" >Loaned From</th>
#       <td id="T_5522a_row0_col0" class="data row0 col0" >9586</td>
#       <td id="T_5522a_row0_col1" class="data row0 col1" >92.066846</td>
#       <td id="T_5522a_row0_col2" class="data row0 col2" >object</td>
#     </tr>
#     <tr>
#       <th id="T_5522a_level0_row1" class="row_heading level0 row1" >Release Clause</th>
#       <td id="T_5522a_row1_col0" class="data row1 col0" >996</td>
#       <td id="T_5522a_row1_col1" class="data row1 col1" >9.565886</td>
#       <td id="T_5522a_row1_col2" class="data row1 col2" >object</td>
#     </tr>
#     <tr>
#       <th id="T_5522a_level0_row2" class="row_heading level0 row2" >Joined</th>
#       <td id="T_5522a_row2_col0" class="data row2 col0" >991</td>
#       <td id="T_5522a_row2_col1" class="data row2 col1" >9.517864</td>
#       <td id="T_5522a_row2_col2" class="data row2 col2" >object</td>
#     </tr>
#     <tr>
#       <th id="T_5522a_level0_row3" class="row_heading level0 row3" >LS</th>
#       <td id="T_5522a_row3_col0" class="data row3 col0" >968</td>
#       <td id="T_5522a_row3_col1" class="data row3 col1" >9.296965</td>
#       <td id="T_5522a_row3_col2" class="data row3 col2" >object</td>
#     </tr>
#     <tr>
#       <th id="T_5522a_level0_row4" class="row_heading level0 row4" >RS</th>
#       <td id="T_5522a_row4_col0" class="data row4 col0" >968</td>
#       <td id="T_5522a_row4_col1" class="data row4 col1" >9.296965</td>
#       <td id="T_5522a_row4_col2" class="data row4 col2" >object</td>
#     </tr>
#     <tr>
#       <th id="T_5522a_level0_row5" class="row_heading level0 row5" >LW</th>
#       <td id="T_5522a_row5_col0" class="data row5 col0" >968</td>
#       <td id="T_5

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(8, 5))

bploting=ax1.boxplot(pd_df_null['Height'],patch_artist=True, boxprops=dict(facecolor="#095599"))
top = bploting['caps'][1].get_data()[1][0]
bot = bploting['caps'][0].get_data()[1][0]
points = bploting['fliers'][0].get_data()[1]
top_points = [ point for point in points if point> top]
bottom_points = [point for point in points if point< bot]
ax1.plot(np.ones(len(top_points)), top_points, "o", color="#ff4040", markersize=3)
ax1.plot(np.ones(len(bottom_points)), bottom_points, "o", color="#ff4040", markersize=3)
fig.subplots_adjust(bottom=0.2, left=0.3, right=1, top=1)

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(7, 7))

bploting=ax1.boxplot(pd_df_null['Weight'],patch_artist=True, boxprops=dict(facecolor="#095599"))
top = bploting['caps'][1].get_data()[1][0]
bot = bploting['caps'][0].get_data()[1][0]
points = bploting['fliers'][0].get_data()[1]
top_points = [ point for point in points if point> top]
bottom_points = [point for point in points if point< bot]
ax1.plot(np.ones(len(top_points)), top_points, "o", color="#ff4040", markersize=3)
ax1.plot(np.ones(len(bottom_points)), bottom_points, "o", color="#ff4040", markersize=3)
fig.subplots_adjust(bottom=0.2, left=0.7, right=1.5, top=1)

# %% [markdown]
# <h4> Answer in markdown cells below the visual
# <br><br>
# <ol>
#     <li>Summarise your findings from the visual.</li>
#     <p> The height values range between 5.1 to 6.7. The weight ranges from 110 to 243. Heights is ditributed normally and don't have any outliers. Weight on the other hand have outliers such as 110 to 119 and 212 to 243.  </p>
#     <li>The reason for selecting the chart type you did.</li>
#     <p> we were asked to plot chart to find the outliers. Box plot is helps us doing it. We added the colors to outliers to be visually different</p>
#     <li>Mention the pre-attentive attributes used.(atleast 2)</li>
#     1) used color to identify the outliers</br>
#     2) used a visualy appealing color for box to show maximum range of values
#     <li>Mention the gestalt principles used.(atleast 2)</li>
#     1) closure - It gives the closure of values with range</br>
#     2) simplicity - we used to simple plot to better covey our information
# </ol>

# %% [markdown]
# ### Question 2
# <h4>Do Bi-Variate anlaysis for outliers detection for height and weight
# <br><br>
# <h4>Write the python code in the below cell to create appropriate visual to perform the above task.
# <h4> Answer in markdown cells below the visual
# <br><br>
# <ol>
#     <li>Summarise your findings from the visual</li>
#     <li>The reason for selecting the chart type you did</li>
#     <li>Mention the pre-attentive attributes used.(atleast 2)</li>
#     <li>Mention the gestalt principles used.(atleast 2)</li>
# </ol>

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))

bplotting = ax1.scatter(x=pd_df_null.Height, y=pd_df_null.Weight, alpha=0.5, linewidths=0.5, marker=".")
plt.xlabel('Height')
plt.ylabel('Weight')
# Out:
# Text(0, 0.5, 'Weight')

# %% [markdown]
# <h4> Answer in markdown cells below the visual
# <br><br>
# <ol>
#     <li>Summarise your findings from the visual</li>
#     <p> The tall people, weighs more. We can see a mismatch in this where people with 5.1 have abnormally high weights. This may be due to incorrectly loaded. </p>
#     <li>The reason for selecting the chart type you did</li>
#     <p> We used to scatter plot to plot the height and weight. The scatter plot is used to plot between two continous patrameters.</p>
#     <li>Mention the pre-attentive attributes used.(atleast 2)</li>
#     1) The area where there are too many points ahve darker shade and the area where points are far way have lighter shade</br>
#     2) used a visualy appealing color and marker for scatter plot to show maximum range of values
#     <li>Mention the gestalt principles used.(atleast 2)</li>
#     1) connectedness - It gives the connection between the height and weight</br>
#     2) proximity - The weight for every player is at some range every height
# </ol>

# %% [markdown]
# ### Question 3
# <h4>What kind of co-relation exists between Age and Overall.
# <br><br>
# Write the python code in the below cell to create appropriate visual to perform the above task.
# <h4> Answer in markdown cells below the visual
# <br><br>
# <ol>
#     <li>Summarise your findings from the visual</li>
#     <li>The reason for selecting the chart type you did.</li>
#     <li>Mention the pre-attentive attributes used.(atleast 2)</li>
#     <li>Mention the gestalt principles used.(atleast 2)</li>
# </ol>

# %%
pd_df_null[['Age', 'Overall']].corr()
# Out:
#               Age   Overall
# Age      1.000000  0.113495
# Overall  0.113495  1.000000

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))

bplotting = ax1.scatter(x=pd_df_null.Age, y=pd_df_null.Overall, alpha=0.5, linewidths=0.5, marker=".")
plt.xlabel('Age')
plt.ylabel('Overall')
# Out:
# Text(0, 0.5, 'Overall')

# %% [markdown]
# <h4> Answer in markdown cells below the visual
# <br><br>
# <ol>
#     <li>Summarise your findings from the visual</li>
#     <p>Players below 20 have the lowest ratings and between 25 to 35 have the highest rating. Players with 31 and 33 have the highest ratings. Most players are rated between 75 to 85.</p>
#     <li>The reason for selecting the chart type you did.</li>
#     <p>Scatter plot is used to plot between 2 indendent continous values. So we used scatter plot to plot the values. </p>
#     <li>Mention the pre-attentive attributes used.(atleast 2)</li>
#     1) The area where there are too many points ahve darker shade and the area where points are far way have lighter shade</br>
#     2) used a visualy appealing color and marker for scatter plot to show maximum range of values
#     <li>Mention the gestalt principles used.(atleast 2)</li>
#     1) connectedness - It gives the connection between the Age and rating</br>
#     2) proximity - The rating of every player for particular age are within some range
# </ol>

# %% [markdown]
#   ### Question 4
# <h4>What kind of relation exists between Age and (potential vs Overall). Create an appropriate visual to compare potential vs Overall with respect to age in one single visual.
# <br><br>
# Write the python code in the below cell to create appropriate visual to perform the above task.
# <h4> Answer in markdown cells below the visual
# <br><br>
# <ol>
#     <li>Summarise your findings from the visual.</li>
#     <li>The reason for selecting the chart type you did.</li>
#     <li>Mention the pre-attentive attributes used.(atleast 2)</li>
#     <li>Mention the gestalt principles used.(atleast 2)</li>
# </ol>

# %%
pd_df_null['Potential'].unique()
# Out:
# array([94, 93, 92, 91, 90, 89, 95, 88, 87, 86, 85, 84, 83, 82, 81, 80, 79,
#        78, 77, 76, 75, 74, 73, 72, 71, 70, 69, 68, 67, 66, 65])

# %%
pd_df_null['Overall'].unique()
# Out:
# array([94, 92, 91, 90, 89, 88, 87, 86, 85, 84, 83, 82, 81, 80, 79, 78, 77,
#        76, 75, 74, 73, 72, 71, 70, 69, 68, 67, 66, 65])

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(10, 7))
c=pd_df_null['Age']
bplotting = ax1.scatter(x=pd_df_null.Potential, y=pd_df_null.Overall, alpha=0.5, linewidths=0.5, marker='.', c=c)
legend1= ax1.legend(*bplotting.legend_elements())
ax1.add_artist(legend1)
plt.xlabel('Potential')
plt.ylabel('Overall')
# Out:
# Text(0, 0.5, 'Overall')

# %% [markdown]
# <h4> Answer in markdown cells below the visual
# <br><br>
# <ol>
#     <li>Summarise your findings from the visual.</li>
#     <p> The younger people have higher potential rating than the overall rating, which mean they can grow. The older they are closer is the values of potential rating and overal rating. As the scope for growth decsreases as they age</p>
#     <li>The reason for selecting the chart type you did.</li>
#     <p> Scatter plot is used to plot to continous values. So we used scatter plot. We were asked to plot age against potential and overall. So we used Age as label and used color attribute to visually different different age players</p>
#     <li>Mention the pre-attentive attributes used.(atleast 2)</li>
#     1) The color is used to represent age of different players</br>
#     2) The potential rating is always greater than or equal to the overall rating
#     <li>Mention the gestalt principles used.(atleast 2)</li>
#     1) connectedness - It gives the connection between the Age and (overall vs potential)</br>
#     2) similarity - This gives the similarity for the given age.
# </ol>

# %% [markdown]
#   ### Question 5
# <h4>What kind of relation exists between Player Vision and Player Value. Create an appropriate visual to show any kind of relation that exists between Vision and Value of the player in one single visual.
# <br><br>
# Write the python code in the below cell to create appropriate visual to perform the above task.
# <h4> Answer in markdown cells below the visual
# <br><br>
# <ol>
#     <li>Summarise your findings from the visual</li>
#     <li>The reason for selecting the chart type you did.</li>
#     <li>Mention the pre-attentive attributes used.(atleast 2)</li>
#     <li>Mention the gestalt principles used.(atleast 2)</li>
# </ol>

# %%
pd_df_null['Vision'].unique()
# Out:
# array([94.        , 82.        , 87.        , 68.        , 89.        ,
#        92.        , 84.        , 63.        , 70.        , 77.        ,
#        86.        , 52.        , 79.        , 80.        , 83.        ,
#        69.        , 44.        , 50.        , 91.        , 90.        ,
#        30.        , 74.        , 72.        , 41.        , 58.        ,
#        64.        , 43.        , 76.        , 65.        , 62.        ,
#        67.        , 59.        , 85.        , 56.        , 88.        ,
#        47.        , 75.        , 93.        , 57.        , 81.        ,
#        66.        , 22.        , 53.        , 78.        , 48.        ,
#        49.        , 27.        , 73.        , 51.        , 54.        ,
#        46.        , 45.        , 42.        , 60.        , 61.        ,
#        71.        , 55.        , 23.        , 37.        , 25.        ,
#        40.        , 34.        , 32.        , 36.        , 28.        ,
#        15.        , 38.        , 33.        , 39.        , 31.        ,
#        16.        , 35.        , 18.        , 14.        , 20.        ,
#        21.        , 11.        , 26.        , 19.        , 17.        ,
#        29.        , 24.        , 13.        , 12.        , 10.        ,
#        58.24195562])

# %%
pd_df_null['Vision']=pd_df_null['Vision'].astype(int)

# %%
pd_df_null['Value'].unique()
# Out:
# array(['€110.5M', '€77M', '€118.5M', '€72M', '€102M', '€93M', '€67M',
#        '€80M', '€51M', '€68M', '€76.5M', '€44M', '€60M', '€63M', '€89M',
#        '€83.5M', '€78M', '€58M', '€53.5M', '€51.5M', '€38M', '€64.5M',
#        '€27M', '€81M', '€69.5M', '€59.5M', '€62M', '€73.5M', '€59M',
#        '€46M', '€43M', '€36M', '€57M', '€24M', '€30M', '€4M', '€64M',
#        '€30.5M', '€62.5M', '€52M', '€45M', '€34M', '€46.5M', '€61M',
#        '€41.5M', '€44.5M', '€56.5M', '€53M', '€50M', '€55M', '€36.5M',
#        '€45.5M', '€43.5M', '€35M', '€39M', '€18M', '€21.5M', '€50.5M',
#        '€54M', '€40.5M', '€37.5M', '€28.5M', '€37M', '€32M', '€26M',
#        '€33M', '€38.5M', '€35.5M', '€9M', '€15.5M', '€22M', '€14M',
#        '€42.5M', '€31.5M', '€42M', '€25M', '€29.5M', '€31M', '€24.5M',
#        '€27.5M', '€29M', '€16.5M', '€23M', '€19M', '€4.2M', '€40M',
#        '€41M', '€28M', '€22.5M', '€34.5M', '€32.5M', '€20M', '€26.5M',
#        '€25.5M', '€21M', '€13M', '€17.5M', '€11.5M', '€8M', '€6M',
#        '€19.5M', '€6.5M', '€20.5M', '€23.5M', '€18.5M', '€17M', '€12.5M',
#        '€15M', '€13.5M', '€4.8M', '€3M', '€1.5M', '€16M', '€10M', '€11M',
#        '€7M', '€14.5M', '€5.5M', '€10.5M', '€4.5M', '€12M', '€0', '€9.5M',
#        '€8.5M', '€2M', '€1.7M', '€1M', '€3.6M', '€7.5M', '€3.8M', '€5M',
#        '€2.4M', '€2.9M', '€4.7M', '€4.1M', '€2.1M', '€600K', '€2.7M',
#        '€3.4M', '€2.5M', '€3.2M', '€3.1M', '€4.9M', '€4.3M', '€2.3M',
#        '€525K', '€3.9M', '€1.8M', '€2.2M', '€4.4M', '€1.6M', '€900K',
#        '€3.7M', '€3.5M', '€1.9M', '€450K', '€775K', '€650K', '€750K',
#        '€2.8M', '€1.3M', '€4.6M', '€2.6M', '€1.2M', '€375K', '€3.3M',
#        '€270K', '€950K', '€550K', '€1.1M', '€975K', '€1.4M', '€725K',
#        '€425K', '€210K', '€875K', '€675K', '€325K', '€800K', '€850K',
#        '€160K', '€120K', '€825K', '€925K', '€625K', '€240K', '€500K',
#        '€575K', '€200K', '€250K', '€700K', '€350K', '€475K', '€300K',
#        '€70K', '€140K', '€230K', '€400K', '€280K', '€100K', '€60K',
#        '€260K', '€180K', '€220K', '€50K', '€290K', '€90K', '€150K',
#        '€40K', '€130K'], dtype=object)

# %%
pd_df_null['Value']=pd_df_null['Value'].apply(lambda x: x.replace('€', ''))
pd_df_null['Value_p']=pd_df_null['Value'].apply(lambda x: eval(x[:-1])/1000 if x[-1]=='K' else x[:-1])
pd_df_null['Value_p']=pd.to_numeric(pd_df_null['Value_p'])
indexAge = pd_df_null[pd_df_null['Value_p'].isnull()].index
pd_df_null.drop(indexAge , inplace=True)

# %%
pd_df_null['Value_p']=pd_df_null['Value_p'].astype(int)

# %%
pd_df_null['Value_p'].unique()
# Out:
# array([110,  77, 118,  72, 102,  93,  67,  80,  51,  68,  76,  44,  60,
#         63,  89,  83,  78,  58,  53,  38,  64,  27,  81,  69,  59,  62,
#         73,  46,  43,  36,  57,  24,  30,   4,  52,  45,  34,  61,  41,
#         56,  50,  55,  35,  39,  18,  21,  54,  40,  37,  28,  32,  26,
#         33,   9,  15,  22,  14,  42,  31,  25,  29,  16,  23,  19,  20,
#         13,  17,  11,   8,   6,  12,   3,   1,  10,   7,   5,   2,   0])

# %%
pd_df_null['Value'].unique()
# Out:
# array(['110.5M', '77M', '118.5M', '72M', '102M', '93M', '67M', '80M',
#        '51M', '68M', '76.5M', '44M', '60M', '63M', '89M', '83.5M', '78M',
#        '58M', '53.5M', '51.5M', '38M', '64.5M', '27M', '81M', '69.5M',
#        '59.5M', '62M', '73.5M', '59M', '46M', '43M', '36M', '57M', '24M',
#        '30M', '4M', '64M', '30.5M', '62.5M', '52M', '45M', '34M', '46.5M',
#        '61M', '41.5M', '44.5M', '56.5M', '53M', '50M', '55M', '36.5M',
#        '45.5M', '43.5M', '35M', '39M', '18M', '21.5M', '50.5M', '54M',
#        '40.5M', '37.5M', '28.5M', '37M', '32M', '26M', '33M', '38.5M',
#        '35.5M', '9M', '15.5M', '22M', '14M', '42.5M', '31.5M', '42M',
#        '25M', '29.5M', '31M', '24.5M', '27.5M', '29M', '16.5M', '23M',
#        '19M', '4.2M', '40M', '41M', '28M', '22.5M', '34.5M', '32.5M',
#        '20M', '26.5M', '25.5M', '21M', '13M', '17.5M', '11.5M', '8M',
#        '6M', '19.5M', '6.5M', '20.5M', '23.5M', '18.5M', '17M', '12.5M',
#        '15M', '13.5M', '4.8M', '3M', '1.5M', '16M', '10M', '11M', '7M',
#        '14.5M', '5.5M', '10.5M', '4.5M', '12M', '9.5M', '8.5M', '2M',
#        '1.7M', '1M', '3.6M', '7.5M', '3.8M', '5M', '2.4M', '2.9M', '4.7M',
#        '4.1M', '2.1M', '600K', '2.7M', '3.4M', '2.5M', '3.2M', '3.1M',
#        '4.9M', '4.3M', '2.3M', '525K', '3.9M', '1.8M', '2.2M', '4.4M',
#        '1.6M', '900K', '3.7M', '3.5M', '1.9M', '450K', '775K', '650K',
#        '750K', '2.8M', '1.3M', '4.6M', '2.6M', '1.2M', '375K', '3.3M',
#        '270K', '950K', '550K', '1.1M', '975K', '1.4M', '725K', '425K',
#        '210K', '875K', '675K', '325K', '800K', '850K', '160K', '120K',
#        '825K', '925K', '625K', '240K', '500K', '575K', '200K', '250K',
#        '700K', '350K', '475K', '300K', '70K', '140K', '230K', '400K',
#        '280K', '100K', '60K', '260K', '180K', '220K', '50K', '290K',
#        '90K', '150K', '40K', '130K'], dtype=object)

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(14, 10))

bplotting = ax1.scatter(x=pd_df_null.Vision, y=pd_df_null.Value_p, alpha=0.5, linewidths=0.5, marker=".")
plt.xlabel('Vision')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %% [markdown]
# <h4> Answer in markdown cells below the visual
# <br><br>
# <ol>
#     <li>Summarise your findings from the visual</li>
#     <p> The players with higher vision has the probablity of having higher value. Most of the players are valued between 1 million to 20 million. some of the players who have vision greater than 40 are valued above 20 million. Most of the players who have vision greater than 80 are valued above 20million</p>
#     <li>The reason for selecting the chart type you did.</li>
#     <p> Scatter plot is used to plot to continous values. So we used scatter plot. We were asked to plot vision against value. </p>
#     <li>Mention the pre-attentive attributes used.(atleast 2)</li>
#     1) The area where there are too many points ahve darker shade and the area where points are far way have lighter shade</br>
#     2) used a visualy appealing color and marker for scatter plot to show maximum range of values
#     <li>Mention the gestalt principles used.(atleast 2)</li>
#     1) connectedness - It gives the connection between the vision and value</br>
#     2) proximity - The values are at close proximity.
# </ol>

# %%
pd_df_null['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
pd_df_null['Overall'].unique()
# Out:
# array([94, 92, 91, 90, 89, 88, 87, 86, 85, 84, 83, 82, 81, 80, 79, 78, 77,
#        76, 75, 74, 73, 72, 71, 70, 69, 68, 67, 66, 65])

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(19, 14))
g = pd_df_null.groupby(['Position'])['Overall']
s = g.mean()
ax1 = s.plot.bar()
plt.xlabel('Position')
plt.ylabel('Overall')

for x, (y, count) in enumerate(zip(s, g.count())):
    ax1.annotate(f'{count}', (x, y), ha='center', va='bottom')

# %% [markdown]
# <h4> Answer in markdown cells below the visual <br><br>
#    1.Summarise your findings from the visual.<br>
#    <p> we have used 2 observations to find. One is the postion with ratings and count. Other one is to find the correlation between special and Overall. LAM, RAM, LF and RF are rarest skillset and are heavily rated. </br>
#     Special and Overall have a corelation. Players with higher speacial ratings have higher overall rating </p>
#    2.The reason for selecting the chart type you did <br>
#    <p> for the first used the barplot to find the count and rating asone of the axis is categorical value.</br>
#    Second one we used scatter plot to plot, as both are continous values</p>
#    3.Mention the pre-attentive attributes used.(atleast 2)<br>
#    4.Mention the gestalt principles used.(atleast 2)<br>

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(14, 10))

bplotting = ax1.scatter(x=pd_df_null.Overall, y=pd_df_null.Special, alpha=0.5, linewidths=0.5, marker=".")
plt.xlabel('Overall')
plt.ylabel('Special')
# Out:
# Text(0, 0.5, 'Special')

# %% [markdown]
# <h4> Answer in markdown cells below the visual <br><br>
#    1.Summarise your findings from the visual.<br>
#    <p> we have used 2 observations to find. One is the postion with ratings and count. Other one is to find the correlation between special and Overall. LAM, RAM, LF and RF are rarest skillset and are heavily rated. </br>
#     Special and Overall have a corelation. Players with higher speacial ratings have higher overall rating </p>
#    2.The reason for selecting the chart type you did <br>
#    <p> for the first used the barplot to find the count and rating asone of the axis is categorical value.</br>
#    Second one we used scatter plot to plot, as both are continous values</p>
#    Mention the pre-attentive attributes used.(atleast 2)</br>
#     1) The area where there are too many points ahve darker shade and the area where points are far way have lighter shade</br>
#     2) used a visualy appealing color and marker for scatter plot to show maximum range of values</br>
#     Mention the gestalt principles used.(atleast 2)</br>
#     1) connectedness - It gives the connection between the vision and value</br>
#     2) proximity - The values are at close proximity.
